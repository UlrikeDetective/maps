# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
# Read the CSV file
df = pd.read_csv('/Users/ulrike_imac_air/projects/maps/Shapefiles/SFPopulationDensity2021.csv', delimiter=';')
df.head()
# Out:
#                  County   Year        Pop  PercentChng_1960  Source  \
# 0        Alameda County  2,021  1,656,591             1.824  DOF_E5
# 1   Contra Costa County  2,021  1,153,854             2.821  DOF_E5
# 2          Marin County  2,021    257,774             1.756  DOF_E5
# 3           Napa County  2,021    137,637             2.089  DOF_E5
# 4  San Francisco County  2,021    875,010             1.182  DOF_E5
#
#   Area_sq_km Pop_Density  Latitude  Longitude
# 0      1,914       865.6   37.6017  -121.7195
# 1      2,045       564.2   37.8534  -121.9018
# 2      2,145       120.2   38.0834  -122.7633
# 3      1,789        77.0   38.5025  -122.2654
# 4        121     7,231.5   37.7749  -122.4194

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = gpd.GeoDataFrame(df, geometry=geometry)
gdf.head()
# Out:
#                  County   Year        Pop  PercentChng_1960  Source  \
# 0        Alameda County  2,021  1,656,591             1.824  DOF_E5
# 1   Contra Costa County  2,021  1,153,854             2.821  DOF_E5
# 2          Marin County  2,021    257,774             1.756  DOF_E5
# 3           Napa County  2,021    137,637             2.089  DOF_E5
# 4  San Francisco County  2,021    875,010             1.182  DOF_E5
#
#   Area_sq_km Pop_Density  Latitude  Longitude                   geometry
# 0      1,914       865.6   37.6017  -121.7195  POINT (-121.7195 37.6017)
# 1      2,045       564.2   37.8534  -121.9018  POINT (-121.9018 37.8534)
# 2      2,145       120.2   38.0834  -122.7633  POINT (-122.7633 38.0834)
# 3      1,789        77.0   38.5025  -122.2654  POINT (-122.2654 38.5025)
# 4        121     7,231.5   37.7749  -122.4194  POINT (-122.4194 37.7749)

# %%
# Save the GeoDataFrame as a shapefile
gdf.to_file('/Users/ulrike_imac_air/projects/maps/Shapefiles/SFPopulationDensity2021.shp')
# Out:
# /var/folders/1_/6h4xg3ts1cd8htbp9t8wjyh40000gn/T/ipykernel_37043/2781143953.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file('/Users/ulrike_imac_air/projects/maps/Shapefiles/SFPopulationDensity2021.shp')
# /Users/ulrike_imac_air/projects/maps/maps_env/lib/python3.11/site-packages/pyogrio/geopandas.py:662: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
# /Users/ulrike_imac_air/projects/maps/maps_env/lib/python3.11/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'PercentChng_1960' to 'PercentChn'
#   ogr_write(
# /Users/ulrike_imac_air/projects/maps/maps_env/lib/python3.11/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Pop_Density' to 'Pop_Densit'
#   ogr_write(

# %%
# prepare the data

import geopandas as gpd

# Load a GeoJSON or shapefile with geographical boundaries (e.g., country borders)
gdf = gpd.read_file('Shapefiles/SFPopulationDensity2021.shp')

# Inspect the data to see what columns are available for visualization
print(gdf.head(10))
# Out:
#                  County   Year        Pop  PercentChn  Source Area_sq_km  \
# 0        Alameda County  2,021  1,656,591       1.824  DOF_E5      1,914
# 1   Contra Costa County  2,021  1,153,854       2.821  DOF_E5      2,045
# 2          Marin County  2,021    257,774       1.756  DOF_E5      2,145
# 3           Napa County  2,021    137,637       2.089  DOF_E5      1,789
# 4  San Francisco County  2,021    875,010       1.182  DOF_E5        121
# 5      San Mateo County  2,021    765,245       1.722  DOF_E5      1,919
# 6    Santa Clara County  2,021  1,934,171       3.011  DOF_E5      3,377
# 7         Solano County  2,021    438,527       3.258  DOF_E5      2,235
# 8         Sonoma County  2,021    484,207       3.286  DOF_E5      4,576
#
#   Pop_Densit  Latitude  Longitude                   geometry
# 0      865.6   37.6017  -121.7195  POINT (-121.7195 37.6017)
# 1      564.2   37.8534  -121.9018  POINT (-121.9018 37.8534)
# ...
