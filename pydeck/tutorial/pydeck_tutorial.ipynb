# %% [markdown]
# # What Is PyDeck?
# PyDeck is a Python library for interactive geospatial visualization.
# It is a Python wrapper around deck.gl, Uber’s powerful WebGL-based visualization framework.
#
# In simple terms:
#
# PyDeck lets you put data on a map and interact with it (zoom, rotate, hover) using Python.
#
# PyDeck is commonly used for:
#
# Mapping GPS points
# Visualizing traffic, delivery routes, or sensor locations
# Creating 3D maps with height, color, and animation
# Building dashboards with Jupyter Notebook, Streamlit, or Dash
#
# ### Why Use PyDeck Instead of Static Maps?
# Traditional plotting libraries (like Matplotlib) create static images.
# PyDeck creates interactive maps that run in your browser.
#
# Key advantages:
# 🗺️ Pan, zoom, rotate maps
# 🎨 Color and size based on data values
# 🧊 3D visualizations (columns, arcs, heatmaps)
# ⚡ GPU-accelerated (fast even for large datasets)
# 📓 Works beautifully in Jupyter Notebooks
#
# ### Installing PyDeck
# ```python
# pip install pydeck
# ```
# PyDeck works best in:
#
# Jupyter Notebook
# JupyterLab
# Streamlit apps
#
# ###Your First PyDeck Map (Scatter Plot)
# Let’s start with a very simple example: plotting points on a map.
#
# Example dataset: city locations

# %%
import pandas as pd

data = pd.DataFrame({
    "city": ["Vancouver", "Toronto", "Montreal"],
    "lat": [49.2827, 43.6532, 45.5017],
    "lon": [-123.1207, -79.3832, -73.5673]
})

# %%
# create a scatter plot

import pydeck as pdk

layer = pdk.Layer(
    "ScatterplotLayer",
    data=data,
    get_position="[lon, lat]",
    get_radius=50000,
    get_color=[0, 128, 255],
    pickable=True
)

view_state = pdk.ViewState(
    latitude=49.2827,
    longitude=-123.1207,
    zoom=3
)

deck = pdk.Deck(
    layers=[layer],
    initial_view_state=view_state,
    tooltip={"text": "{city}"}
)

deck
deck.to_html("scatterplot.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 49.2827,
#     &quot;longitude&quot;: -123.1207,
#     &quot;zoom&quot;: 3
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;city&quot;: &quot;Vancouver&quot;,
#           &quot;lat&quot;: 49.2827,
#           &quot;lon&quot;: -123.1207
#         },
#         {
#           &quot;city&quot;: &quot;Toronto&quot;,
#           &quot;lat&quot;: 43.6532,
#           &quot;lon&quot;: -79.3832
#         },
#         {
#           &quot;city&quot;: &quot;Montreal&quot;,
#           &quot;lat&quot;: 45.5017,
#           &quot;lon&quot;: -73.5673
#         }
#       ],
#       &quot;getColor&quot;: [
#         0,
#         128,
#         255
#       ],
#       &quot;getPosition&quot;: &quot;@@=[lon, lat]&quot;,
#       &quot;getRadius&quot;: 50000,
#       &quot;id&quot;: &quot;b3fd5f65-30df-488c-93b9-712f541d80d2&quot;,
#       &quot;pickable&quot;: true
#     }
#   ],
#   &quot;mapProvider&quot;: &quot;carto&quot;,
#   &quot;mapStyle&quot;: &quot;https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json&quot;,
#   &quot;views&quot;: [
#     {
#       &quot;@@type&quot;: &quot;MapView&quot;,
#       &quot;controller&quot;: true
#     }
#   ]
# };
#     const tooltip = {&#x27;text&#x27;: &#x27;{city}&#x27;};
#     const customLibraries = null;
#     const configuration = null;
#
#     const deckInstance = createDeck({
#                   container,
#       jsonInput,
#       tooltip,
#       customLibraries,
#       configuration
#     });
#
#   &lt;/script&gt;
# &lt;/html&gt;"
#         ></iframe>

# %% [markdown]
# ### 3D Column Map (Very Popular Example)
# This is where PyDeck really shines.
#
# Example: population by city

# %%
data = pd.DataFrame({
    "city": ["Vancouver", "Toronto", "Montreal"],
    "lat": [49.2827, 43.6532, 45.5017],
    "lon": [-123.1207, -79.3832, -73.5673],
    "population": [675000, 2930000, 1760000]
})

# %%
import streamlit as st
import pydeck as pdk    

layer = pdk.Layer(
    "ColumnLayer",
    data=data,
    get_position="[lon, lat]",
    get_elevation="population / 1000",
    elevation_scale=50,
    radius=30000,
    get_fill_color=[255, 100, 100],
    pickable=True,
    auto_highlight=True
)

view_state = pdk.ViewState(
    latitude=45,
    longitude=-75,
    zoom=4,
    pitch=45
)

deck = pdk.Deck(
    layers=[layer],
    initial_view_state=view_state,
    tooltip={"text": "{city}\nPopulation: {population}"}
)
deck.show()
st.pydeck_chart(deck)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 28
#      16 view_state = pdk.ViewState(
#      17     latitude=45,
#      18     longitude=-75,
#      19     zoom=4,
#      20     pitch=45
#      21 )
#      23 pdk.Deck(
#      24     layers=[layer],
#      25     initial_view_state=view_state,
#      26     tooltip={"text": "{city}\nPopulation: {population}"}
#      27 )
# ---> 28 Deck.show()
#      29 st.pydeck_chart(deck)
#
# NameError: name 'Deck' is not defined
