# %% [markdown]
# ## QuackOSM – a hassle-free tool for reading OSM data
# To end this article I want to highlight a library that can automatically download the OSM data, filter it by the geometry or using OSM tags and save it as a GeoParquet file that can be easily integrated into more scalable solutions. The library is written in Python and is open-source.

# %%
# %pip install quackosm

# %%
import quackosm as qosm
dir(qosm)
# Out:
# ['PbfFileReader',
#  '__all__',
#  '__app_name__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_constants',
#  '_exceptions',
#  '_geoparquet_metadata',
#  '_intersection',
#  '_osm_tags_filters',
#  '_osm_way_polygon_features',
#  '_parquet_multiprocessing',
#  '_rich_progress',
#  '_typing',
#  'convert_geometry_to_duckdb',
#  'convert_geometry_to_geodataframe',
#  'convert_geometry_to_parquet',
#  'convert_osm_extract_to_duckdb',
#  'convert_osm_extract_to_geodataframe',
#  'convert_osm_extract_to_parquet',
#  'convert_pbf_to_duckdb',
#  'convert_pbf_to_geodataframe',
#  'convert_pbf_to_parquet',
#  'display_available_extracts',
#  'functions',
#  'geocode',
#  'geocode_to_geometry',
#  'osm_extracts',
#  'pbf_file_reader']

# %%
import quackosm as qosm
help(qosm)
# Out:
# Help on package quackosm:
#
# NAME
#     quackosm - QuackOSM.
#
# DESCRIPTION
#     QuackOSM is a Python library used for reading pbf (ProtoBuffer) files with OpenStreetMap data using
#     DuckDB spatial extension without GDAL.
#
# PACKAGE CONTENTS
#     __main__
#     _constants
#     _exceptions
#     _geohash_parser
#     _geoparquet_metadata
#     _intersection
#     _osm_tags_filters
#     _osm_way_polygon_features
#     _parquet_multiprocessing
#     _rich_progress
#     _typing
#     cli
#     functions
#     geocode
#     osm_extracts (package)
#     pbf_file_reader
#
# CLASSES
#     builtins.object
#         quackosm.pbf_file_reader.PbfFileReader
#
#     class PbfFileReader(builtins.object)
#      |  PbfFileReader(
#      |      tags_filter: Union[collections.abc.Mapping[str, Union[list[str], str, bool]], collections.abc.Mapping[str, collections.abc.Mapping[str, Union[list[str], str, bool]]], NoneType] = None,
# ...

# %%
# For Jupyter Notebook or JupyterLab
# %pip install ipywidgets

# %%
import quackosm as qosm

# Path to your OSM PBF file
pbf_path = "Helsinki.osm.pbf"

# Convert .osm.pbf to a GeoDataFrame
gdf = qosm.convert_pbf_to_geodataframe(pbf_path)

# Inspect the first few rows
print(gdf.head())

# Optional: filter for specific feature types
# For example, only buildings
buildings = gdf[gdf["osm_type"] == "building"]
print(buildings.head())
# Out:
# Output()
